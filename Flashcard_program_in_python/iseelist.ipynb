# %%
import sys
import random
import shelve
import datetime
from datetime import timedelta, datetime, date
import pandas as pd
import numpy as np

# %%
def to_cardlist(df):
    word_list = []
    for index, row in df.iterrows():
        wordcard = {}
        wordcard['index'] = index
        wordcard['word'] = row[0]
        wordcard['definition'] = row[1]
        wordcard['consecutive right'] = row[3]
        word_list.append(wordcard)
    return word_list

def card_return(answer, card):
    if answer[0].lower() == 'r':
        try:
            word_list = word_list[:card['consecutive right']*5] +card+ word_list[card['consecutive right']*5:]
        except:
            print('Error in card_return')
            word_list.append(card)
    elif answer[0].lower() == 'm':
        try:
            word_list = word_list[:card['consecutive right']*10] +card+ word_list[card['consecutive right']*10:]
        except:
            print('Error in card_return')
            word_list.append(card)
    else:
        try:
            word_list = word_list[:5] +card+ word_list[5:]
        except:
            print('Error in card_return')
            word_list.append(card)


def fc():
    df = pd.read_csv('isee_csv.csv')
    
    
    word_list = to_cardlist(df) 

    for card in word_list[:10]:
        print(card)

    print("You have " + str(len(word_list)) + " words in today's list.\n\n\n")
    while len(word_list) > 0:
        print(word_list[0]['word'] + '\n\n')
        answer = input('Enter definition: ')
        print('\n\n' + word_list[0]['definition'] + '\n\n')
        card = word_list.pop(0)
        correct = input(
            ' Did you get the question right or wrong or have you mastered the concept (type r, w, m or q)? ')
        try:
            if correct[0].lower() == 'r':
                card['consecutive right'] += 1
                card_return('r', card)
            elif correct[0].lower() == 'm':
                card['consecutive right'] += 1
                card_return('m', card)
            elif correct[0].lower() == 'q':
                break
            else:
                card['consecutive right'] = 1
                card_return('w', card)
        except:
            df.to_csv('isee_csv.csv', index=False)
            print('An error has occoured.')
            print('Returning to main menu.')

# %%
wl = fc()
print(wl)
# Out:
# {'index': 0, 'word': 'abandon', 'definition': 'leave someone who needs or counts on you', 'consecutive right': 0}
# {'index': 1, 'word': 'Abate', 'definition': 'become less in amount or intensity', 'consecutive right': 0}
# {'index': 2, 'word': 'abdicate', 'definition': 'give up power, duties or obligations', 'consecutive right': 0}
# {'index': 3, 'word': 'abduct (v.)', 'definition': 'to kidnap ', 'consecutive right': 0}
# {'index': 4, 'word': 'abase (v.)', 'definition': 'to lower, demean, degrade', 'consecutive right': 0}
# {'index': 5, 'word': 'abscond (v.)', 'definition': 'to sneak away and hide', 'consecutive right': 0}
# {'index': 6, 'word': 'abate (v.)', 'definition': 'to lessen, to reduce in severity', 'consecutive right': 0}
# {'index': 7, 'word': 'abbreviate (v.)', 'definition': 'to shorten, reduce', 'consecutive right': 0}
# {'index': 8, 'word': 'abundant (adj.)', 'definition': 'in great numbers', 'consecutive right': 0}
# {'index': 9, 'word': 'accede (v.)', 'definition': 'to agree', 'consecutive right': 0}
# You have 499 words in today's list.
#
#
#
# abandon
#
#
#
#
# leave someone who needs or counts on you
#
#
# An error has occoured.
# Returning to main menu.
# Abate
#
#
#
#
# become less in amount or intensity
#
#
# An error has occoured.
# Returning to main menu.
# abdicate
#
#
#
#
# give up power, duties or obligations
#
#
# An error has occoured.
# Returning to main menu.
# abduct (v.)
#
#
#
#
# to kidnap
#
#
# An error has occoured.
# Returning to main menu.
# abase (v.)
#
#
#
#
# to lower, demean, degrade
#
#
# An error has occoured.
# Returning to main menu.
# abscond (v.)
#
#
#
#
# to sneak away and hide
#
#
# An error has occoured.
# Returning to main menu.
# abate (v.)
#
#
#
#
# to lessen, to reduce in severity
#
#
# An error has occoured.
# Returning to main menu.
# abbreviate (v.)
#
#
#
#
# to shorten, reduce
#
#
# None

# %%
df1 = pd.DataFrame(wl)

# %%
df1.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.read_csv('isee_csv.csv')
    
word_list = to_cardlist(df)

# %%
df1 = pd.DataFrame(word_list)

df1.set_index('word', inplace=True)

df1.head()
# Out:
#              index                                definition  date  \
# word
# abandon          0  leave someone who needs or counts on you   NaN
# Abate            1        become less in amount or intensity   NaN
# abdicate         2      give up power, duties or obligations   NaN
# abduct (v.)      3                                to kidnap    NaN
# abase (v.)       4                 to lower, demean, degrade   NaN
#
#              consecutive right  card used
# word
# abandon                      0          0
# Abate                        0          0
# abdicate                     0          0
# abduct (v.)                  0          0
# abase (v.)                   0          0

# %%
df1['']
